# %% [markdown]
# [Reference](https://ridgerunai.medium.com/machine-learning-mean-average-precision-map-and-other-object-detection-metrics-45267507a904)

# %%
def iou(bbox_a, bbox_b):
    ax1, ay1, ax2, ay2 = bbox_a
    bx1, by1, bx2, by2 = bbox_b

    # Compute the coordinates of the intersection
    ix1 = max(ax1, bx1)
    iy1 = max(ay1, by1)
    ix2 = min(ax2, bx2)
    iy2 = min(ay2, by2)

    # Compute the area of intersection rectangle
    intersection = max(0, ix2 - ix1) * max(0, iy2 - iy1)

    # Compute the area of both bounding boxes
    box1_area = (ax2 - ax1) * (ay2 - ay1)
    box2_area = (bx2 - bx1) * (by2 - by1)

    # Finally compute the union of the areas
    union = box1_area + box2_area - intersection


    return intersection / union

# %%
# !pip3 install ultralytics
# !pip3 install requests
# !pip3 install pycocotools
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.2.17-py3-none-any.whl (757 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.0/757.0 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.8.0.76)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.17.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, thop, ultralytics
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 thop-0.1.1.post2209072238 ultralytics-8.2.17
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.2.2)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (2.0.7)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pycocotools) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from pycocotools) (1.25.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1.0->pycocotools) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.16.0)

# %%
# To download a sample dataset
import requests
import zipfile
from tqdm import tqdm

# An example model
from ultralytics import YOLO

# COCO tools
from pycocotools.coco import COCO
from pycocotools.cocoeval import COCOeval

# To check if we need to re-download
import os

# Helper to download files
def download_file(url, file_path):
    response = requests.get(url, stream=True)
    total_size_in_bytes = int(response.headers.get('content-length', 0))
    block_size = 1024  # 1 Kibibyte

    progress_bar = tqdm(total=total_size_in_bytes, unit='iB', unit_scale=True)

    with open(file_path, 'wb') as file:
        for data in response.iter_content(block_size):
            progress_bar.update(len(data))
            file.write(data)
    progress_bar.close()

coco_url = "https://github.com/ultralytics/yolov5/releases/download/v1.0/coco2017val.zip"
coco_zip_path = 'coco2017val.zip'

# Only download and unzip if the coco directory is not there
if not os.path.exists('coco'):
    download_file(coco_url, coco_zip_path)

    # Unzip the file
    with zipfile.ZipFile(coco_zip_path, 'r') as zip_ref:
        zip_ref.extractall('.')

# Load pre-trained YOLOv8 model
model = YOLO('./yolov8n.pt')

# Load COCO validation images annotations
coco_annotations_path = 'coco/annotations/instances_val2017.json'
coco = COCO(coco_annotations_path)

# Get image IDs
image_ids = coco.getImgIds()
images = coco.loadImgs(image_ids)

# Process images and collect detections
results = []
for img in images:
    image_path = f"coco/images/val2017/{img['file_name']}"
    preds = model(image_path)[0].numpy().boxes

    # Convert results to a COCO compatible format
    for xyxy, conf, cls in zip(preds.xyxy, preds.conf, preds.cls):
        result = {
            'image_id': img['id'],
            'category_id': int(cls.item()+1),
            'bbox': [xyxy[0].item(), xyxy[1].item(), xyxy[2].item() - xyxy[0].item(), xyxy[3].item() - xyxy[1].item()],
            'score': conf.item()
        }

        results.append(result)

# Convert results to COCO object
coco_dt = coco.loadRes(results)

# Run COCO evaluation
coco_eval = COCOeval(coco, coco_dt, 'bbox')
coco_eval.evaluate()
coco_eval.accumulate()
coco_eval.summarize()
# Out:
# 100%|██████████| 818M/818M [00:18<00:00, 45.3MiB/s]
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 98.3MB/s]
# Streaming output truncated to the last 5000 lines.
# image 1/1 /content/coco/images/val2017/000000433204.jpg: 480x640 5 persons, 2 cars, 1 motorcycle, 174.8ms
# Speed: 2.6ms preprocess, 174.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000
8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000190676.jpg: 288x640 20 persons, 1 airplane, 128.3ms
# Speed: 1.3ms preprocess, 128.3ms inference, 1.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/coco/images/val2017/000000170545.jpg: 480x640 1 car, 6 traffic lights, 177.2ms
# Speed: 2.6ms preprocess, 177.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000269942.jpg: 640x480 1 person, 1 car, 2 traffic lights, 174.1ms
# Speed: 2.1ms preprocess, 174.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/coco/images/val2017/000000269682.jpg: 480x640 11 traffic lights, 172.6ms
# Speed: 2.1ms preprocess, 172.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000109441.jpg: 480x640 5 traffic lights, 172.0ms
# Speed: 2.1ms preprocess, 172.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000001584.jpg: 640x640 4 persons, 3 buss, 236.2ms
# Speed: 4.9ms preprocess, 236.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/coco/images/val2017/000000289586.jpg: 640x448 1 giraffe, 167.0ms
# Speed: 2.0ms preprocess, 167.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/coco/images/val2017/000000079034.jpg: 480x640 4 cars, 1 fire hydrant, 173.6ms
# Speed: 2.0ms preprocess, 173.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000140583.jpg: 480x640 3 persons, 1 car, 15 sheeps, 171.2ms
# Speed: 2.1ms preprocess, 171.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000026926.jpg: 640x448 2 cars, 1 fire hydrant, 172.5ms
# Speed: 2.1ms preprocess, 172.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/coco/images/val2017/000000499775.jpg: 480x640 1 car, 1 bus, 203.5ms
# Speed: 2.9ms preprocess, 203.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000153632.jpg: 480x640 1 fork, 1 knife, 2 bowls, 1 cake, 1 dining table, 195.9ms
# Speed: 2.9ms preprocess, 195.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000523782.jpg: 480x640 1 car, 1 truck, 207.1ms
# Speed: 2.7ms preprocess, 207.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000285788.jpg: 512x640 1 bird, 2 giraffes, 209.1ms
# Speed: 3.0ms preprocess, 209.1ms inference, 2.0ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /content/coco/images/val2017/000000053529.jpg: 448x640 1 person, 1 dog, 179.4ms
# Speed: 3.4ms preprocess, 179.4ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000042888.jpg: 480x640 1 traffic light, 252.6ms
# Speed: 4.6ms preprocess, 252.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000072852.jpg: 640x448 2 persons, 1 bicycle, 1 handbag, 261.9ms
# Speed: 2.1ms preprocess, 261.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/coco/images/val2017/000000153527.jpg: 480x640 3 persons, 3 benchs, 5 chairs, 271.9ms
# Speed: 4.3ms preprocess, 271.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000276707.jpg: 480x640 1 person, 1 car, 301.6ms
# Speed: 4.1ms preprocess, 301.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000184324.jpg: 448x640 14 persons, 2 bicycles, 7 cars, 2 motorcycles, 1 truck, 1 handbag, 264.9ms
# Speed: 5.0ms preprocess, 264.9ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000127624.jpg: 640x640 (no detections), 381.2ms
# Speed: 5.8ms preprocess, 381.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/coco/images/val2017/000000522940.jpg: 640x512 1 stop sign, 336.8ms
# Speed: 6.0ms preprocess, 336.8ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /content/coco/images/val2017/000000460229.jpg: 640x384 1 truck, 2 traffic lights, 1 stop sign, 251.5ms
# Speed: 7.5ms preprocess, 251.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /content/coco/images/val2017/000000364587.jpg: 448x640 1 train, 282.1ms
# Speed: 2.8ms preprocess, 282.1ms inference, 1.9ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000212072.jpg: 480x640 1 fire hydrant, 1 stop sign, 1 potted plant, 316.8ms
# Speed: 4.1ms preprocess, 316.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000192607.jpg: 448x640 1 person, 1 car, 1 truck, 268.4ms
# Speed: 2.6ms preprocess, 268.4ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000052565.jpg: 480x640 1 cow, 280.2ms
# Speed: 4.2ms preprocess, 280.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000525247.jpg: 448x640 1 cat, 1 laptop, 180.8ms
# Speed: 3.2ms preprocess, 180.8ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000424545.jpg: 480x640 1 cat, 200.0ms
# Speed: 4.2ms preprocess, 200.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000416758.jpg: 480x640 5 cows, 192.3ms
# Speed: 2.9ms preprocess, 192.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000004395.jpg: 640x448 1 person, 1 tie, 184.5ms
# Speed: 3.4ms preprocess, 184.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/coco/images/val2017/000000490470.jpg: 480x640 1 person, 3 boats, 194.1ms
# Speed: 2.6ms preprocess, 194.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000296657.jpg: 448x640 6 persons, 180.4ms
# Speed: 2.6ms preprocess, 180.4ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000354547.jpg: 640x448 1 person, 1 tie, 199.1ms
# Speed: 3.4ms preprocess, 199.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/coco/images/val2017/000000262048.jpg: 640x640 6 persons, 1 umbrella, 252.8ms
# Speed: 5.8ms preprocess, 252.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/coco/images/val2017/000000519208.jpg: 416x640 1 person, 2 elephants, 1 couch, 176.8ms
# Speed: 2.4ms preprocess, 176.8ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/coco/images/val2017/000000270402.jpg: 448x640 1 bird, 3 elephants, 175.9ms
# Speed: 3.1ms preprocess, 175.9ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000250127.jpg: 640x640 1 person, 1 train, 1 bench, 1 umbrella, 2 handbags, 259.7ms
# Speed: 3.5ms preprocess, 259.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/coco/images/val2017/000000549930.jpg: 576x640 2 persons, 1 bench, 2 umbrellas, 223.5ms
# Speed: 3.4ms preprocess, 223.5ms inference, 1.8ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /content/coco/images/val2017/000000112626.jpg: 640x448 1 suitcase, 1 couch, 187.0ms
# Speed: 2.7ms preprocess, 187.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/coco/images/val2017/000000000285.jpg: 640x608 1 bear, 227.9ms
# Speed: 3.6ms preprocess, 227.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /content/coco/images/val2017/000000573391.jpg: 480x640 1 bear, 177.3ms
# Speed: 2.2ms preprocess, 177.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000447200.jpg: 480x640 2 dogs, 182.7ms
# Speed: 2.0ms preprocess, 182.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000261036.jpg: 640x448 4 persons, 3 frisbees, 166.8ms
# Speed: 3.7ms preprocess, 166.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/coco/images/val2017/000000269932.jpg: 640x480 1 horse, 177.2ms
# Speed: 4.2ms preprocess, 177.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/coco/images/val2017/000000426297.jpg: 448x640 1 zebra, 169.1ms
# Speed: 2.1ms preprocess, 169.1ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000068933.jpg: 416x640 3 zebras, 168.7ms
# Speed: 3.6ms preprocess, 168.7ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/coco/images/val2017/000000047571.jpg: 640x640 1 person, 1 horse, 255.5ms
# Speed: 3.4ms preprocess, 255.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/coco/images/val2017/000000023126.jpg: 448x640 1 person, 1 horse, 180.3ms
# Speed: 2.7ms preprocess, 180.3ms inference, 1.8ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000242678.jpg: 512x640 1 person, 1 bench, 1 horse, 202.6ms
# Speed: 2.9ms preprocess, 202.6ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /content/coco/images/val2017/000000229948.jpg: 448x640 10 persons, 1 truck, 3 horses, 174.1ms
# Speed: 2.6ms preprocess, 174.1ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000451879.jpg: 576x640 5 persons, 1 sports ball, 1 baseball glove, 237.1ms
# Speed: 4.8ms preprocess, 237.1ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /content/coco/images/val2017/000000158660.jpg: 640x640 2 persons, 2 bowls, 2 bananas, 3 apples, 1 dining table, 247.4ms
# Speed: 5.5ms preprocess, 247.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/coco/images/val2017/000000059598.jpg: 480x640 2 persons, 1 cup, 1 banana, 1 cake, 1 chair, 1 dining table, 2 laptops, 1 mouse, 1 cell phone, 1 book, 199.4ms
# Speed: 3.2ms preprocess, 199.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000485480.jpg: 288x640 3 persons, 1 baseball glove, 121.2ms
# Speed: 2.0ms preprocess, 121.2ms inference, 1.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /content/coco/images/val2017/000000006012.jpg: 544x640 3 bananas, 1 apple, 209.6ms
# Speed: 3.1ms preprocess, 209.6ms inference, 2.1ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /content/coco/images/val2017/000000013201.jpg: 640x448 1 person, 1 skateboard, 193.3ms
# Speed: 2.6ms preprocess, 193.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/coco/images/val2017/000000243989.jpg: 576x640 5 persons, 224.7ms
# Speed: 5.1ms preprocess, 224.7ms inference, 1.7ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /content/coco/images/val2017/000000044260.jpg: 448x640 (no detections), 179.1ms
# Speed: 2.8ms preprocess, 179.1ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000581357.jpg: 640x640 5 persons, 1 skateboard, 251.4ms
# Speed: 6.0ms preprocess, 251.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/coco/images/val2017/000000476119.jpg: 448x640 1 person, 4 cars, 1 skateboard, 186.2ms
# Speed: 2.9ms preprocess, 186.2ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000287667.jpg: 480x640 1 knife, 2 carrots, 1 dining table, 2 mouses, 193.1ms
# Speed: 2.7ms preprocess, 193.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000527784.jpg: 512x640 4 bottles, 1 fork, 3 sandwichs, 1 chair, 1 dining table, 207.0ms
# Speed: 3.4ms preprocess, 207.0ms inference, 1.7ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /content/coco/images/val2017/000000179898.jpg: 480x640 8 persons, 2 hot dogs, 4 chairs, 2 dining tables, 193.2ms
# Speed: 2.8ms preprocess, 193.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000349152.jpg: 640x480 12 donuts, 1 dining table, 195.3ms
# Speed: 2.6ms preprocess, 195.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/coco/images/val2017/000000187055.jpg: 640x448 3 persons, 2 sports balls, 1 bottle, 203.3ms
# Speed: 2.6ms preprocess, 203.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/coco/images/val2017/000000493334.jpg: 416x640 1 cake, 1 cell phone, 180.3ms
# Speed: 3.6ms preprocess, 180.3ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/coco/images/val2017/000000318455.jpg: 480x640 18 cakes, 1 dining table, 193.4ms
# Speed: 2.8ms preprocess, 193.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000520659.jpg: 480x640 11 persons, 190.6ms
# Speed: 2.9ms preprocess, 190.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000465430.jpg: 544x640 2 sandwichs, 1 oven, 206.5ms
# Speed: 2.9ms preprocess, 206.5ms inference, 1.6ms postprocess per image at shape (1, 3, 544, 640)
#
# image 1/1 /content/coco/images/val2017/000000209829.jpg: 480x640 3 persons, 204.0ms
# Speed: 2.7ms preprocess, 204.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000329080.jpg: 480x640 3 beds, 245.3ms
# Speed: 3.0ms preprocess, 245.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000190307.jpg: 640x544 1 person, 338.9ms
# Speed: 3.2ms preprocess, 338.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /content/coco/images/val2017/000000200421.jpg: 480x640 1 person, 1 tennis racket, 301.8ms
# Speed: 2.6ms preprocess, 301.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000551820.jpg: 448x640 12 persons, 272.1ms
# Speed: 3.5ms preprocess, 272.1ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000254368.jpg: 640x416 1 person, 1 chair, 1 bed, 254.8ms
# Speed: 2.4ms preprocess, 254.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /content/coco/images/val2017/000000146489.jpg: 480x640 1 bottle, 2 wine glasss, 1 pizza, 1 dining table, 275.8ms
# Speed: 2.8ms preprocess, 275.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000438304.jpg: 640x480 2 persons, 1 sports ball, 3 tennis rackets, 323.9ms
# Speed: 2.8ms preprocess, 323.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/coco/images/val2017/000000033368.jpg: 640x448 1 person, 1 tennis racket, 275.8ms
# Speed: 2.8ms preprocess, 275.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/coco/images/val2017/000
2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000308193.jpg: 640x480 1 clock, 189.1ms
# Speed: 2.9ms preprocess, 189.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/coco/images/val2017/000000424135.jpg: 640x480 (no detections), 174.3ms
# ...
# Speed: 2.2ms preprocess, 178.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/coco/images/val2017/000000290768.jpg: 640x640 3 bottles, 228.5ms
# Speed: 4.9ms preprocess, 228.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/coco/images/val2017/000000357567.jpg: 640x480 2 toilets, 173.0ms
# Speed: 2.0ms preprocess, 173.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/coco/images/val2017/000000237118.jpg: 640x608 1 person, 1 cell phone, 223.6ms
# Speed: 2.7ms preprocess, 223.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /content/coco/images/val2017/000000343561.jpg: 448x640 11 persons, 7 bicycles, 160.5ms
# Speed: 2.0ms preprocess, 160.5ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000195165.jpg: 480x640 5 bottles, 2 bowls, 1 toilet, 1 sink, 187.3ms
# Speed: 2.3ms preprocess, 187.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000023272.jpg: 480x640 3 cars, 2 cats, 189.6ms
# Speed: 4.2ms preprocess, 189.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000464689.jpg: 640x608 2 bottles, 242.4ms
# Speed: 3.2ms preprocess, 242.4ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 608)
#
# image 1/1 /content/coco/images/val2017/000000360943.jpg: 640x512 1 cat, 219.6ms
# Speed: 3.0ms preprocess, 219.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 512)
#
# image 1/1 /content/coco/images/val2017/000000410221.jpg: 640x640 1 airplane, 261.0ms
# Speed: 3.7ms preprocess, 261.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/coco/images/val2017/000000245513.jpg: 512x640 1 bird, 1 giraffe, 208.2ms
# Speed: 4.4ms preprocess, 208.2ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /content/coco/images/val2017/000000445365.jpg: 640x448 2 giraffes, 176.7ms
# Speed: 2.9ms preprocess, 176.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/coco/images/val2017/000000059386.jpg: 640x448 5 giraffes, 192.8ms
# Speed: 2.5ms preprocess, 192.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/coco/images/val2017/000000279714.jpg: 640x448 2 cars, 175.2ms
# Speed: 2.7ms preprocess, 175.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/coco/images/val2017/000000507042.jpg: 640x448 3 giraffes, 182.2ms
# Speed: 4.0ms preprocess, 182.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/coco/images/val2017/000000314541.jpg: 448x640 1 bench, 180.8ms
# Speed: 2.7ms preprocess, 180.8ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000341921.jpg: 480x640 1 person, 1 car, 2 traffic lights, 1 bench, 181.5ms
# Speed: 2.9ms preprocess, 181.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000186449.jpg: 640x448 8 persons, 3 benchs, 193.2ms
# Speed: 2.5ms preprocess, 193.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/coco/images/val2017/000000547336.jpg: 480x640 1 person, 187.0ms
# Speed: 2.7ms preprocess, 187.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000226154.jpg: 512x640 3 persons, 1 motorcycle, 1 bus, 206.2ms
# Speed: 4.4ms preprocess, 206.2ms inference, 1.6ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /content/coco/images/val2017/000000394275.jpg: 416x640 4 persons, 1 bus, 164.9ms
# Speed: 2.6ms preprocess, 164.9ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/coco/images/val2017/000000229753.jpg: 448x640 2 giraffes, 183.3ms
# Speed: 2.5ms preprocess, 183.3ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000261712.jpg: 480x640 2 giraffes, 207.7ms
# Speed: 3.0ms preprocess, 207.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000019042.jpg: 384x640 1 person, 1 bird, 1 sheep, 163.8ms
# Speed: 2.5ms preprocess, 163.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/coco/images/val2017/000000534394.jpg: 384x640 1 car, 11 sheeps, 157.9ms
# Speed: 2.6ms preprocess, 157.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/coco/images/val2017/000000322610.jpg: 480x640 6 persons, 4 umbrellas, 3 handbags, 2 suitcases, 192.4ms
# Speed: 3.0ms preprocess, 192.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000263299.jpg: 448x640 1 train, 185.3ms
# Speed: 3.5ms preprocess, 185.3ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000236690.jpg: 416x640 1 bird, 179.8ms
# Speed: 3.4ms preprocess, 179.8ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /content/coco/images/val2017/000000252559.jpg: 640x480 9 persons, 200.7ms
# Speed: 2.9ms preprocess, 200.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/coco/images/val2017/000000050145.jpg: 448x640 2 persons, 1 bicycle, 1 umbrella, 1 handbag, 167.9ms
# Speed: 3.0ms preprocess, 167.9ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000467848.jpg: 480x640 1 person, 3 cars, 2 trucks, 169.0ms
# Speed: 2.1ms preprocess, 169.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000572388.jpg: 640x448 1 cat, 2 bananas, 3 donuts, 163.3ms
# Speed: 3.5ms preprocess, 163.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/coco/images/val2017/000000272212.jpg: 480x640 5 cows, 183.4ms
# Speed: 2.2ms preprocess, 183.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000377000.jpg: 640x544 1 cat, 196.7ms
# Speed: 2.6ms preprocess, 196.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /content/coco/images/val2017/000000198641.jpg: 480x640 1 cat, 2 tvs, 1 laptop, 1 mouse, 1 keyboard, 174.6ms
# Speed: 2.2ms preprocess, 174.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000181421.jpg: 448x640 4 persons, 1 boat, 2 umbrellas, 162.5ms
# Speed: 2.0ms preprocess, 162.5ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000477227.jpg: 448x640 2 trains, 163.2ms
# Speed: 2.0ms preprocess, 163.2ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000119641.jpg: 480x640 15 persons, 8 elephants, 187.4ms
# Speed: 2.2ms preprocess, 187.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000040083.jpg: 448x640 3 persons, 1 bicycle, 2 cars, 2 chairs, 168.9ms
# Speed: 3.4ms preprocess, 168.9ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000244496.jpg: 640x384 1 person, 1 tie, 160.7ms
# Speed: 2.9ms preprocess, 160.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /content/coco/images/val2017/000000565624.jpg: 384x640 1 cow, 1 elephant, 153.1ms
# Speed: 2.3ms preprocess, 153.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/coco/images/val2017/000000549220.jpg: 640x480 3 persons, 1 dog, 1 skateboard, 187.1ms
# Speed: 3.2ms preprocess, 187.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/coco/images/val2017/000000442836.jpg: 480x640 3 persons, 1 frisbee, 256.4ms
# Speed: 2.8ms preprocess, 256.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000428218.jpg: 480x640 2 persons, 1 frisbee, 1 tennis racket, 291.8ms
# Speed: 2.9ms preprocess, 291.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000574297.jpg: 448x640 1 person, 1 horse, 265.7ms
# Speed: 2.6ms preprocess, 265.7ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000061747.jpg: 576x640 1 person, 1 skis, 350.9ms
# Speed: 3.3ms preprocess, 350.9ms inference, 2.4ms postprocess per image at shape (1, 3, 576, 640)
#
# image 1/1 /content/coco/images/val2017/000000553788.jpg: 384x640 1 person, 1 bed, 1 laptop, 1 book, 232.6ms
# Speed: 2.5ms preprocess, 232.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/coco/images/val2017/000000153510.jpg: 448x640 4 broccolis, 260.5ms
# Speed: 2.5ms preprocess, 260.5ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000456143.jpg: 384x640 1 bowl, 1 sandwich, 1 carrot, 231.1ms
# Speed: 2.3ms preprocess, 231.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /content/coco/images/val2017/000000157418.jpg: 640x480 1 bottle, 2 cups, 2 bowls, 2 sandwichs, 1 dining table, 307.8ms
# Speed: 4.1ms preprocess, 307.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/coco/images/val2017/000000345469.jpg: 640x480 16 donuts, 309.8ms
# Speed: 3.2ms preprocess, 309.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/coco/images/val2017/000000533855.jpg: 448x640 1 donut, 281.2ms
# Speed: 2.6ms preprocess, 281.2ms inference, 2.1ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000389197.jpg: 448x640 6 persons, 1 dog, 1 surfboard, 289.2ms
# Speed: 2.7ms preprocess, 289.2ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000422998.jpg: 448x640 2 persons, 3 bottles, 1 cup, 1 knife, 1 sandwich, 1 dining table, 276.3ms
# Speed: 2.6ms preprocess, 276.3ms inference, 2.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000000632.jpg: 512x640 1 bottle, 1 chair, 2 potted plants, 1 bed, 2 books, 269.6ms
# Speed: 3.9ms preprocess, 269.6ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /content/coco/images/val2017/000000477955.jpg: 640x480 1 person, 1 frisbee, 1 kite, 192.6ms
# Speed: 2.8ms preprocess, 192.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/coco/images/val2017/000000128675.jpg: 480x640 3 persons, 1 kite, 1 surfboard, 203.1ms
# Speed: 3.0ms preprocess, 203.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000402720.jpg: 640x640 3 persons, 4 bottles, 8 wine glasss, 1 pizza, 2 dining tables, 1 cell phone, 250.4ms
# Speed: 6.0ms preprocess, 250.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# image 1/1 /content/coco/images/val2017/000000179141.jpg: 480x640 4 persons, 1 bottle, 1 cup, 1 pizza, 188.4ms
# Speed: 3.5ms preprocess, 188.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000353096.jpg: 448x640 1 tv, 1 mouse, 1 keyboard, 179.3ms
# Speed: 4.1ms preprocess, 179.3ms inference, 1.6ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /content/coco/images/val2017/000000013729.jpg: 480x640 4 persons, 1 backpack, 2 bottles, 1 couch, 1 dining table, 1 tv, 3 remotes, 194.6ms
# Speed: 3.0ms preprocess, 194.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000391140.jpg: 480x640 1 person, 208.1ms
# Speed: 2.8ms preprocess, 208.1ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000157046.jpg: 480x640 (no detections), 191.1ms
# Speed: 5.6ms preprocess, 191.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000384527.jpg: 480x640 1 bottle, 1 cup, 1 bowl, 1 cake, 3 chairs, 1 dining table, 1 book, 1 vase, 189.7ms
# Speed: 2.8ms preprocess, 189.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000478721.jpg: 480x640 4 persons, 2 cars, 4 trucks, 194.3ms
# Speed: 3.9ms preprocess, 194.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000033759.jpg: 480x640 1 person, 1 sports ball, 196.7ms
# Speed: 4.0ms preprocess, 196.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000098287.jpg: 640x416 9 persons, 184.7ms
# Speed: 2.9ms preprocess, 184.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 416)
#
# image 1/1 /content/coco/images/val2017/000000158227.jpg: 480x640 1 person, 1 sports ball, 1 baseball bat, 173.9ms
# Speed: 3.6ms preprocess, 173.9ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# image 1/1 /content/coco/images/val2017/000000407646.jpg: 512x640 1 person, 1 sports ball, 1 tennis racket, 189.8ms
# Speed: 4.0ms preprocess, 189.8ms inference, 1.3ms postprocess per image at shape (1, 3, 512, 640)
#
# image 1/1 /content/coco/images/val2017/000000220310.jpg: 640x448 2 cars, 1 teddy bear, 163.9ms
# Speed: 6.2ms preprocess, 163.9ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/coco/images/val2017/000000512403.jpg: 640x544 1 knife, 1 potted plant, 1 vase, 194.5ms
# Speed: 2.2ms preprocess, 194.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 544)
#
# image 1/1 /content/coco/images/val2017/000000168974.jpg: 640x480 2 persons, 197.0ms
# Speed: 3.6ms preprocess, 197.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/coco/images/val2017/000000552775.jpg: 640x480 1 person, 1 bottle, 2 spoons, 197.2ms
# Speed: 4.1ms preprocess, 197.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
#
# image 1/1 /content/coco/images/val2017/000000394940.jpg: 640x448 2 persons, 2 knifes, 1 cake, 1 dining table, 191.3ms
# Speed: 2.7ms preprocess, 191.3ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 448)
#
# image 1/1 /content/coco/images/val2017/000000015335.jpg: 480x640 4 persons, 1 cup, 199.2ms
# Speed: 2.8ms preprocess, 199.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Loading and preparing results...
# DONE (t=0.08s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=18.32s).
# Accumulating evaluation results...
# DONE (t=4.25s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.053
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.071
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.058
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.052
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.083
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.043
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.061
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.061
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.027
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.062
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.094
