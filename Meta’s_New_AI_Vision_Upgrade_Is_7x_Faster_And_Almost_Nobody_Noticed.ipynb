# %% [markdown]
# [Reference](https://www.towardsdeeplearning.com/metas-new-ai-vision-upgrade-is-7x-faster-and-almost-nobody-noticed-eb2fd14c5cf2)

# %%
# Clone the repo and install
# !git clone https://github.com/facebookresearch/sam3.git
# %cd sam3
# Out:
# Cloning into 'sam3'...
# remote: Enumerating objects: 1051, done.
# remote: Total 1051 (delta 0), reused 0 (delta 0), pack-reused 1051 (from 1)
# Receiving objects: 100% (1051/1051), 60.33 MiB | 29.76 MiB/s, done.
# Resolving deltas: 100% (252/252), done.
# /content/sam3

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/sam3
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 87.8 MB/s eta 0:00:00
# ...
#   Building editable for sam3 (pyproject.toml) ... done
#   Created wheel for sam3: filename=sam3-0.1.0-0.editable-py3-none-any.whl size=15717 sha256=e77fa98b58edd65a98302660c412c33104d7bf44870322bd729236aace7bddfd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-peexgqqu/wheels/7c/90/be/80339bb9db8655024d6c9501da4e5efc6abbda4c897f5a6c43
# ...

# %%
# !pip install triton --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.3/188.3 MB 6.5 MB/s eta 0:00:00
# ...

# %%
from PIL import Image
from sam3.model_builder import build_sam3_image_model
from sam3.model.sam3_image_processor import Sam3Processor
# Out:
# /content/sam3/sam3/model/sam3_video_inference.py:801: UserWarning: CUDA is not available or torch_xla is imported. Disabling autocast.
#   @torch.autocast(device_type="cuda", dtype=torch.bfloat16)
# /content/sam3/sam3/model/sam3_video_inference.py:909: UserWarning: CUDA is not available or torch_xla is imported. Disabling autocast.
#   @torch.autocast(device_type="cuda", dtype=torch.bfloat16)
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)

# %%
# Load model and processor
model = build_sam3_image_model()
processor = Sam3Processor(model)
# Load an image and set a text prompt
image = Image.open("your_photo.jpg")
inference_state = processor.set_image(image)
output = processor.set_text_prompt(
    state=inference_state,
    prompt="yellow school bus"
)
# Get masks, bounding boxes, and confidence scores
masks, boxes, scores = output["masks"], output["boxes"], output["scores"]

# %%
from sam3.model_builder import build_sam3_video_predictor
video_predictor = build_sam3_video_predictor()
video_path = "your_video.mp4"  # or a folder of JPEG frames
