# %% [markdown]
# [Reference](https://pub.aimind.so/build-a-resnet-from-scratch-with-tensorflow-2-and-keras-0be0d4c19271)

# %%
import os
import numpy as np
import tensorflow
from tensorflow.keras import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Add, GlobalAveragePooling2D,\
 Dense, Flatten, Conv2D, Lambda, Input, BatchNormalization, Activation
from tensorflow.keras.optimizers import schedules, SGD
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint

def model_configuration():
 """
  Get configuration variables for the model.
 """

 # Load dataset for computing dataset size
 (input_train, _), (_, _) = load_dataset()

 # Generic config
 width, height, channels = 32, 32, 3
 batch_size = 128
 num_classes = 10
 validation_split = 0.1 # 45/5 per the He et al. paper
 verbose = 1
 n = 3
 init_fm_dim = 16
 shortcut_type = "identity" # or: projection

 # Dataset size
 train_size = (1 - validation_split) * len(input_train)
 val_size = (validation_split) * len(input_train)

 # Number of steps per epoch is dependent on batch size
 maximum_number_iterations = 64000 # per the He et al. paper

 # Convert to regular Python integers instead of TensorFlow tensors
 steps_per_epoch = int(train_size // batch_size)  # Use // for integer division
 val_steps_per_epoch = int(val_size // batch_size)  # Use // for integer division
 epochs = int(maximum_number_iterations // steps_per_epoch)  # Use // for integer division

 # Define loss function
 loss = tensorflow.keras.losses.CategoricalCrossentropy(from_logits=True)

 # Learning rate config per the He et al. paper
 boundaries = [32000, 48000]
 values = [0.1, 0.01, 0.001]
 lr_schedule = schedules.PiecewiseConstantDecay(boundaries, values)

 # Set layer init
 initializer = tensorflow.keras.initializers.HeNormal()

 # Define optimizer
 optimizer_momentum = 0.9
 optimizer_additional_metrics = ["accuracy"]
 optimizer = SGD(learning_rate=lr_schedule, momentum=optimizer_momentum)

 # Load Tensorboard callback
 tensorboard = TensorBoard(
   log_dir=os.path.join(os.getcwd(), "logs"),
   histogram_freq=1,
   write_images=True
 )

 # Save a model checkpoint after every epoch
 checkpoint = ModelCheckpoint(
  os.path.join(os.getcwd(), "model_checkpoint.keras"),
  save_freq="epoch"
 )

 # Add callbacks to list
 callbacks = [
   tensorboard,
   checkpoint
 ]

 # Create config dictionary
 config = {
  "width": width,
  "height": height,
  "dim": channels,
  "batch_size": batch_size,
  "num_classes": num_classes,
  "validation_split": validation_split,
  "verbose": verbose,
  "stack_n": n,
  "initial_num_feature_maps": init_fm_dim,
  "training_ds_size": train_size,
  "steps_per_epoch": steps_per_epoch,
  "val_steps_per_epoch": val_steps_per_epoch,
  "num_epochs": epochs,
  "loss": loss,
  "optim": optimizer,
  "optim_learning_rate_schedule": lr_schedule,
  "optim_momentum": optimizer_momentum,
  "optim_additional_metrics": optimizer_additional_metrics,
  "initializer": initializer,
  "callbacks": callbacks,
  "shortcut_type": shortcut_type
 }

 return config



def load_dataset():
 """
  Load the CIFAR-10 dataset
 """
 return cifar10.load_data()


def random_crop(img, random_crop_size):
    # Note: image_data_format is 'channel_last'
    # SOURCE: https://jkjung-avt.github.io/keras-image-cropping/
    assert img.shape[2] == 3
    height, width = img.shape[0], img.shape[1]
    dy, dx = random_crop_size
    x = np.random.randint(0, width - dx + 1)
    y = np.random.randint(0, height - dy + 1)
    return img[y:(y+dy), x:(x+dx), :]


def crop_generator(batches, crop_length):
    """Take as input a Keras ImageGen (Iterator) and generate random
    crops from the image batches generated by the original iterator.
    SOURCE: https://jkjung-avt.github.io/keras-image-cropping/
    """
    while True:
        batch_x, batch_y = next(batches)
        batch_crops = np.zeros((batch_x.shape[0], crop_length, crop_length, 3))
        for i in range(batch_x.shape[0]):
            batch_crops[i] = random_crop(batch_x[i], (crop_length, crop_length))
        yield (batch_crops, batch_y)


def preprocessed_dataset():
 """
  Load and preprocess the CIFAR-10 dataset.
 """
 (input_train, target_train), (input_test, target_test) = load_dataset()

 # Retrieve shape from model configuration and unpack into components
 config = model_configuration()
 width, height, dim = config.get("width"), config.get("height"),\
  config.get("dim")
 num_classes = config.get("num_classes")

 # Data augmentation: perform zero padding on datasets
 paddings = tensorflow.constant([[0, 0,], [4, 4], [4, 4], [0, 0]])
 input_train = tensorflow.pad(input_train, paddings, mode="CONSTANT")

 # Convert scalar targets to categorical ones
 target_train = tensorflow.keras.utils.to_categorical(target_train, num_classes)
 target_test = tensorflow.keras.utils.to_categorical(target_test, num_classes)

 # Data generator for training data
 train_generator = tensorflow.keras.preprocessing.image.ImageDataGenerator(
  validation_split = config.get("validation_split"),
  horizontal_flip = True,
  rescale = 1./255,
  preprocessing_function = tensorflow.keras.applications.resnet50.preprocess_input
 )

 # Generate training and validation batches
 train_batches = train_generator.flow(input_train, target_train, batch_size=config.get("batch_size"), subset="training")
 validation_batches = train_generator.flow(input_train, target_train, batch_size=config.get("batch_size"), subset="validation")
 train_batches = crop_generator(train_batches, config.get("height"))
 validation_batches = crop_generator(validation_batches, config.get("height"))

 # Data generator for testing data
 test_generator = tensorflow.keras.preprocessing.image.ImageDataGenerator(
  preprocessing_function = tensorflow.keras.applications.resnet50.preprocess_input,
  rescale = 1./255)

 # Generate test batches
 test_batches = test_generator.flow(input_test, target_test, batch_size=config.get("batch_size"))

 return train_batches, validation_batches, test_batches



def residual_block(x, number_of_filters, match_filter_size=False):
 """
  Residual block with
 """
 # Retrieve initializer
 config = model_configuration()
 initializer = config.get("initializer")

 # Create skip connection
 x_skip = x

 # Perform the original mapping
 if match_filter_size:
  x = Conv2D(number_of_filters, kernel_size=(3, 3), strides=(2,2),\
   kernel_initializer=initializer, padding="same")(x_skip)
 else:
  x = Conv2D(number_of_filters, kernel_size=(3, 3), strides=(1,1),\
   kernel_initializer=initializer, padding="same")(x_skip)
 x = BatchNormalization(axis=3)(x)
 x = Activation("relu")(x)
 x = Conv2D(number_of_filters, kernel_size=(3, 3),\
  kernel_initializer=initializer, padding="same")(x)
 x = BatchNormalization(axis=3)(x)

 # Perform matching of filter numbers if necessary
 if match_filter_size and config.get("shortcut_type") == "identity":
  x_skip = Lambda(lambda x: tensorflow.pad(x[:, ::2, ::2, :], tensorflow.constant([[0, 0,], [0, 0], [0, 0], [number_of_filters//4, number_of_filters//4]]), mode="CONSTANT"))(x_skip)
 elif match_filter_size and config.get("shortcut_type") == "projection":
  x_skip = Conv2D(number_of_filters, kernel_size=(1,1),\
   kernel_initializer=initializer, strides=(2,2))(x_skip)

 # Add the skip connection to the regular mapping
 x = Add()([x, x_skip])

 # Nonlinearly activate the result
 x = Activation("relu")(x)

 # Return the result
 return x


def ResidualBlocks(x):
 """
  Set up the residual blocks.
 """
 # Retrieve values
 config = model_configuration()

 # Set initial filter size
 filter_size = config.get("initial_num_feature_maps")

 # Paper: "Then we use a stack of 6n layers (...)
 # with 2n layers for each feature map size."
 # 6n/2n = 3, so there are always 3 groups.
 for layer_group in range(3):

  # Each block in our code has 2 weighted layers,
  # and each group has 2n such blocks,
  # so 2n/2 = n blocks per group.
  for block in range(config.get("stack_n")):

   # Perform filter size increase at every
   # first layer in the 2nd block onwards.
   # Apply Conv block for projecting the skip
   # connection.
   if layer_group > 0 and block == 0:
    filter_size *= 2
    x = residual_block(x, filter_size, match_filter_size=True)
   else:
    x = residual_block(x, filter_size)

 # Return final layer
 return x


def model_base(shp):
 """
  Base structure of the model, with residual blocks
  attached.
 """
 # Get number of classes from model configuration
 config = model_configuration()
 initializer = model_configuration().get("initializer")

 # Define model structure
 # logits are returned because Softmax is pushed to loss function.
 inputs = Input(shape=shp)
 x = Conv2D(config.get("initial_num_feature_maps"), kernel_size=(3,3),\
  strides=(1,1), kernel_initializer=initializer, padding="same")(inputs)
 x = BatchNormalization()(x)
 x = Activation("relu")(x)
 x = ResidualBlocks(x)
 x = GlobalAveragePooling2D()(x)
 x = Flatten()(x)
 outputs = Dense(config.get("num_classes"), kernel_initializer=initializer)(x)

 return inputs, outputs


def init_model():
 """
  Initialize a compiled ResNet model.
 """
 # Get shape from model configuration
 config = model_configuration()

 # Get model base
 inputs, outputs = model_base((config.get("width"), config.get("height"),\
  config.get("dim")))

 # Initialize and compile model
 model = Model(inputs, outputs, name=config.get("name"))
 model.compile(loss=config.get("loss"),\
      optimizer=config.get("optim"),\
       metrics=config.get("optim_additional_metrics"))

 # Print model summary
 model.summary()

 return model


def train_model(model, train_batches, validation_batches):
 """
  Train an initialized model.
 """

 # Get model configuration
 config = model_configuration()

 # Fit data to model
 model.fit(train_batches,
           batch_size=config.get("batch_size"),
           epochs=config.get("num_epochs"),
           verbose=config.get("verbose"),
           callbacks=config.get("callbacks"),
           steps_per_epoch=config.get("steps_per_epoch"),
           validation_data=validation_batches,
           validation_steps=config.get("val_steps_per_epoch"))

 return model


def evaluate_model(model, test_batches):
 """
  Evaluate a trained model.
 """
 # Evaluate model
 score = model.evaluate(test_batches, verbose=0)
 print(f'Test loss: {score[0]} / Test accuracy: {score[1]}')


def training_process():
 """
  Run the training process for the ResNet model.
 """

 # Get dataset
 train_batches, validation_batches, test_batches = preprocessed_dataset()

 # Initialize ResNet
 resnet = init_model()

 # Train ResNet model
 trained_resnet = train_model(resnet, train_batches, validation_batches)

 # Evalute trained ResNet model post training
 evaluate_model(trained_resnet, test_batches)


if __name__ == "__main__":
 training_process()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │        448 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 32, 32,    │         64 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 32, 32,    │      2,320 │ activation[0][0]  │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32,    │      2,320 │ activation_1[0][… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 32, 32,    │          0 │ add[0][0]         │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 32, 32,    │      2,320 │ activation_2[0][… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │      2,320 │ activation_3[0][… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 32, 32,    │          0 │ add_1[0][0]       │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │      2,320 │ activation_4[0][… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │      2,320 │ activation_5[0][… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 32, 32,    │          0 │ add_2[0][0]       │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │      4,640 │ activation_6[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │      9,248 │ activation_7[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 16, 16,    │          0 │ activation_6[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ lambda[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 16, 16,    │          0 │ add_3[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │      9,248 │ activation_8[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │      9,248 │ activation_9[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 16, 16,    │          0 │ add_4[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 16, 16,    │      9,248 │ activation_10[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 16, 16,    │      9,248 │ activation_11[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │ activation_10[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 16, 16,    │          0 │ add_5[0][0]       │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 8, 8, 64)  │     18,496 │ activation_12[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 8, 8, 64)  │     36,928 │ activation_13[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 8, 8, 64)  │          0 │ activation_12[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_6 (Add)         │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │                     │                   │            │ lambda_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 8, 8, 64)  │          0 │ add_6[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 8, 8, 64)  │     36,928 │ activation_14[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 8, 8, 64)  │     36,928 │ activation_15[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_7 (Add)         │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_14[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 8, 8, 64)  │          0 │ add_7[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 8, 8, 64)  │     36,928 │ activation_16[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 8, 8, 64)  │     36,928 │ activation_17[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_8 (Add)         │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_16[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_18       │ (None, 8, 8, 64)  │          0 │ add_8[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ activation_18[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 64)        │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 10)        │        650 │ flatten[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 271,786 (1.04 MB)
#  Trainable params: 270,410 (1.03 MB)
#  Non-trainable params: 1,376 (5.38 KB)
# Epoch 1/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 28s 38ms/step - accuracy: 0.2914 - loss: 2.0331 - val_accuracy: 0.3888 - val_loss: 1.7212
# Epoch 2/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 39ms/step - accuracy: 0.5311 - loss: 1.2948 - val_accuracy: 0.5555 - val_loss: 1.3143
# Epoch 3/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 11s 33ms/step - accuracy: 0.6537 - loss: 0.9718 - val_accuracy: 0.5877 - val_loss: 1.2329
# Epoch 4/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.7158 - loss: 0.8028 - val_accuracy: 0.7042 - val_loss: 0.8394
# Epoch 5/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.7535 - loss: 0.7037 - val_accuracy: 0.6242 - val_loss: 1.2264
# Epoch 6/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.7813 - loss: 0.6328 - val_accuracy: 0.6700 - val_loss: 1.0230
# Epoch 7/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.7976 - loss: 0.5820 - val_accuracy: 0.7254 - val_loss: 0.7808
# Epoch 8/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.8076 - loss: 0.5539 - val_accuracy: 0.7580 - val_loss: 0.7169
# Epoch 9/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 60ms/step - accuracy: 0.8177 - loss: 0.5216 - val_accuracy: 0.7748 - val_loss: 0.6623
# Epoch 10/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - accuracy: 0.8340 - loss: 0.4799 - val_accuracy: 0.7906 - val_loss: 0.6061
# Epoch 11/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.8349 - loss: 0.4710 - val_accuracy: 0.7693 - val_loss: 0.6738
# Epoch 12/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.8487 - loss: 0.4406 - val_accuracy: 0.7999 - val_loss: 0.5795
# Epoch 13/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.8556 - loss: 0.4188 - val_accuracy: 0.7755 - val_loss: 0.6696
# Epoch 14/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.8572 - loss: 0.4065 - val_accuracy: 0.7586 - val_loss: 0.7854
# Epoch 15/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.8609 - loss: 0.3958 - val_accuracy: 0.7960 - val_loss: 0.6477
# Epoch 16/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.8652 - loss: 0.3843 - val_accuracy: 0.7872 - val_loss: 0.6371
# Epoch 17/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.8724 - loss: 0.3676 - val_accuracy: 0.7026 - val_loss: 0.9325
# Epoch 18/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.8778 - loss: 0.3532 - val_accuracy: 0.7939 - val_loss: 0.6436
# Epoch 19/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.8803 - loss: 0.3417 - val_accuracy: 0.8161 - val_loss: 0.5611
# Epoch 20/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.8874 - loss: 0.3270 - val_accuracy: 0.8192 - val_loss: 0.5679
# Epoch 21/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.8877 - loss: 0.3214 - val_accuracy: 0.8309 - val_loss: 0.4887
# Epoch 22/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.8905 - loss: 0.3130 - val_accuracy: 0.8194 - val_loss: 0.5727
# Epoch 23/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.8944 - loss: 0.3033 - val_accuracy: 0.8073 - val_loss: 0.5764
# Epoch 24/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.8988 - loss: 0.2860 - val_accuracy: 0.8428 - val_loss: 0.4960
# Epoch 25/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.8980 - loss: 0.2886 - val_accuracy: 0.8364 - val_loss: 0.5009
# Epoch 26/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.9045 - loss: 0.2765 - val_accuracy: 0.8483 - val_loss: 0.4665
# Epoch 27/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.9034 - loss: 0.2692 - val_accuracy: 0.8674 - val_loss: 0.4272
# Epoch 28/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9085 - loss: 0.2661 - val_accuracy: 0.8526 - val_loss: 0.4413
# Epoch 29/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.9108 - loss: 0.2568 - val_accuracy: 0.8321 - val_loss: 0.5378
# Epoch 30/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.9114 - loss: 0.2543 - val_accuracy: 0.8438 - val_loss: 0.4746
# Epoch 31/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9150 - loss: 0.2417 - val_accuracy: 0.8553 - val_loss: 0.4326
# Epoch 32/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9176 - loss: 0.2352 - val_accuracy: 0.8015 - val_loss: 0.6429
# Epoch 33/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9168 - loss: 0.2344 - val_accuracy: 0.8227 - val_loss: 0.6213
# Epoch 34/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 60ms/step - accuracy: 0.9168 - loss: 0.2355 - val_accuracy: 0.8411 - val_loss: 0.5185
# Epoch 35/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9202 - loss: 0.2280 - val_accuracy: 0.8489 - val_loss: 0.4627
# Epoch 36/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9209 - loss: 0.2220 - val_accuracy: 0.8329 - val_loss: 0.5325
# Epoch 37/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9227 - loss: 0.2166 - val_accuracy: 0.8440 - val_loss: 0.5354
# Epoch 38/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9254 - loss: 0.2054 - val_accuracy: 0.8467 - val_loss: 0.4630
# Epoch 39/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 60ms/step - accuracy: 0.9265 - loss: 0.2048 - val_accuracy: 0.7748 - val_loss: 0.9324
# Epoch 40/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9291 - loss: 0.2005 - val_accuracy: 0.8268 - val_loss: 0.6281
# Epoch 41/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9295 - loss: 0.1956 - val_accuracy: 0.8444 - val_loss: 0.5124
# Epoch 42/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9290 - loss: 0.1980 - val_accuracy: 0.8395 - val_loss: 0.5475
# Epoch 43/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9337 - loss: 0.1915 - val_accuracy: 0.8474 - val_loss: 0.5320
# Epoch 44/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9332 - loss: 0.1833 - val_accuracy: 0.8586 - val_loss: 0.4524
# Epoch 45/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9370 - loss: 0.1764 - val_accuracy: 0.8532 - val_loss: 0.5326
# Epoch 46/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.9356 - loss: 0.1769 - val_accuracy: 0.8641 - val_loss: 0.4352
# Epoch 47/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9377 - loss: 0.1688 - val_accuracy: 0.8610 - val_loss: 0.4744
# Epoch 48/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9378 - loss: 0.1770 - val_accuracy: 0.8459 - val_loss: 0.5276
# Epoch 49/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9401 - loss: 0.1666 - val_accuracy: 0.8547 - val_loss: 0.5121
# Epoch 50/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.9427 - loss: 0.1612 - val_accuracy: 0.8200 - val_loss: 0.6474
# Epoch 51/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9406 - loss: 0.1657 - val_accuracy: 0.8598 - val_loss: 0.4601
# Epoch 52/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9440 - loss: 0.1588 - val_accuracy: 0.8534 - val_loss: 0.4972
# Epoch 53/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9425 - loss: 0.1602 - val_accuracy: 0.8405 - val_loss: 0.6221
# Epoch 54/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9437 - loss: 0.1571 - val_accuracy: 0.8493 - val_loss: 0.5103
# Epoch 55/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9480 - loss: 0.1445 - val_accuracy: 0.8596 - val_loss: 0.4630
# Epoch 56/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9460 - loss: 0.1493 - val_accuracy: 0.8744 - val_loss: 0.4383
# Epoch 57/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.9467 - loss: 0.1473 - val_accuracy: 0.8742 - val_loss: 0.4765
# Epoch 58/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9505 - loss: 0.1393 - val_accuracy: 0.8645 - val_loss: 0.4419
# Epoch 59/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.9496 - loss: 0.1384 - val_accuracy: 0.8559 - val_loss: 0.5205
# Epoch 60/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9489 - loss: 0.1427 - val_accuracy: 0.8512 - val_loss: 0.5343
# Epoch 61/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9510 - loss: 0.1385 - val_accuracy: 0.8413 - val_loss: 0.5866
# Epoch 62/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.9531 - loss: 0.1306 - val_accuracy: 0.8654 - val_loss: 0.4579
# Epoch 63/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.9521 - loss: 0.1335 - val_accuracy: 0.8551 - val_loss: 0.5282
# Epoch 64/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9537 - loss: 0.1315 - val_accuracy: 0.8602 - val_loss: 0.4679
# Epoch 65/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9566 - loss: 0.1166 - val_accuracy: 0.8799 - val_loss: 0.4136
# Epoch 66/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9537 - loss: 0.1270 - val_accuracy: 0.8534 - val_loss: 0.5440
# Epoch 67/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9530 - loss: 0.1309 - val_accuracy: 0.8639 - val_loss: 0.5217
# Epoch 68/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9557 - loss: 0.1216 - val_accuracy: 0.8516 - val_loss: 0.4968
# Epoch 69/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 60ms/step - accuracy: 0.9572 - loss: 0.1190 - val_accuracy: 0.8707 - val_loss: 0.4480
# Epoch 70/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9590 - loss: 0.1127 - val_accuracy: 0.8606 - val_loss: 0.5012
# Epoch 71/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.9571 - loss: 0.1191 - val_accuracy: 0.8758 - val_loss: 0.4584
# Epoch 72/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9599 - loss: 0.1083 - val_accuracy: 0.8750 - val_loss: 0.4879
# Epoch 73/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9624 - loss: 0.1045 - val_accuracy: 0.8621 - val_loss: 0.5381
# Epoch 74/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9602 - loss: 0.1106 - val_accuracy: 0.8807 - val_loss: 0.4543
# Epoch 75/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.9615 - loss: 0.1079 - val_accuracy: 0.8758 - val_loss: 0.4439
# Epoch 76/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9610 - loss: 0.1082 - val_accuracy: 0.8723 - val_loss: 0.5138
# Epoch 77/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9612 - loss: 0.1088 - val_accuracy: 0.8565 - val_loss: 0.5683
# Epoch 78/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9613 - loss: 0.1060 - val_accuracy: 0.8783 - val_loss: 0.4912
# Epoch 79/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9609 - loss: 0.1036 - val_accuracy: 0.8664 - val_loss: 0.5620
# Epoch 80/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.9601 - loss: 0.1109 - val_accuracy: 0.8672 - val_loss: 0.5387
# Epoch 81/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9655 - loss: 0.0979 - val_accuracy: 0.8828 - val_loss: 0.4548
# Epoch 82/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.9649 - loss: 0.0957 - val_accuracy: 0.8717 - val_loss: 0.5158
# Epoch 83/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9633 - loss: 0.1015 - val_accuracy: 0.8820 - val_loss: 0.4572
# Epoch 84/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.9666 - loss: 0.0964 - val_accuracy: 0.8473 - val_loss: 0.6093
# Epoch 85/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9650 - loss: 0.0972 - val_accuracy: 0.8666 - val_loss: 0.4845
# Epoch 86/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9659 - loss: 0.0933 - val_accuracy: 0.8732 - val_loss: 0.4867
# Epoch 87/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9659 - loss: 0.0968 - val_accuracy: 0.8698 - val_loss: 0.5492
# Epoch 88/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9674 - loss: 0.0886 - val_accuracy: 0.8752 - val_loss: 0.5184
# Epoch 89/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9693 - loss: 0.0883 - val_accuracy: 0.8676 - val_loss: 0.5239
# Epoch 90/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.9693 - loss: 0.0869 - val_accuracy: 0.8760 - val_loss: 0.4820
# Epoch 91/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9676 - loss: 0.0897 - val_accuracy: 0.8764 - val_loss: 0.4996
# Epoch 92/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 60ms/step - accuracy: 0.9693 - loss: 0.0850 - val_accuracy: 0.8966 - val_loss: 0.3973
# Epoch 93/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9844 - loss: 0.0449 - val_accuracy: 0.8966 - val_loss: 0.3794
# Epoch 94/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9839 - loss: 0.0455 - val_accuracy: 0.8988 - val_loss: 0.3891
# Epoch 95/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9867 - loss: 0.0404 - val_accuracy: 0.9025 - val_loss: 0.3869
# Epoch 96/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9875 - loss: 0.0383 - val_accuracy: 0.8970 - val_loss: 0.3797
# Epoch 97/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 35ms/step - accuracy: 0.9882 - loss: 0.0344 - val_accuracy: 0.9035 - val_loss: 0.3874
# Epoch 98/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.9900 - loss: 0.0314 - val_accuracy: 0.8986 - val_loss: 0.3805
# Epoch 99/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9877 - loss: 0.0363 - val_accuracy: 0.8992 - val_loss: 0.3931
# Epoch 100/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9904 - loss: 0.0306 - val_accuracy: 0.9078 - val_loss: 0.3546
# Epoch 101/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.9895 - loss: 0.0316 - val_accuracy: 0.9017 - val_loss: 0.3924
# Epoch 102/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9897 - loss: 0.0313 - val_accuracy: 0.8998 - val_loss: 0.4051
# Epoch 103/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 60ms/step - accuracy: 0.9901 - loss: 0.0300 - val_accuracy: 0.9062 - val_loss: 0.3809
# Epoch 104/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.9897 - loss: 0.0314 - val_accuracy: 0.9019 - val_loss: 0.4110
# Epoch 105/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9903 - loss: 0.0285 - val_accuracy: 0.8998 - val_loss: 0.4029
# Epoch 106/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9909 - loss: 0.0268 - val_accuracy: 0.9019 - val_loss: 0.4142
# Epoch 107/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9910 - loss: 0.0283 - val_accuracy: 0.9009 - val_loss: 0.3973
# Epoch 108/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9910 - loss: 0.0274 - val_accuracy: 0.9041 - val_loss: 0.4137
# Epoch 109/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.9922 - loss: 0.0266 - val_accuracy: 0.9041 - val_loss: 0.3960
# Epoch 110/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9915 - loss: 0.0269 - val_accuracy: 0.9005 - val_loss: 0.4297
# Epoch 111/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.9929 - loss: 0.0246 - val_accuracy: 0.9023 - val_loss: 0.4034
# Epoch 112/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.9923 - loss: 0.0248 - val_accuracy: 0.8998 - val_loss: 0.4475
# Epoch 113/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9904 - loss: 0.0271 - val_accuracy: 0.9009 - val_loss: 0.4270
# Epoch 114/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 33ms/step - accuracy: 0.9925 - loss: 0.0239 - val_accuracy: 0.9015 - val_loss: 0.4047
# Epoch 115/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - accuracy: 0.9921 - loss: 0.0256 - val_accuracy: 0.8992 - val_loss: 0.4278
# Epoch 116/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9930 - loss: 0.0217 - val_accuracy: 0.9029 - val_loss: 0.4470
# Epoch 117/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - accuracy: 0.9927 - loss: 0.0229 - val_accuracy: 0.8996 - val_loss: 0.4169
# Epoch 118/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 21s 60ms/step - accuracy: 0.9930 - loss: 0.0224 - val_accuracy: 0.9054 - val_loss: 0.4165
# Epoch 119/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9927 - loss: 0.0226 - val_accuracy: 0.8988 - val_loss: 0.4531
# Epoch 120/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 20s 57ms/step - accuracy: 0.9925 - loss: 0.0233 - val_accuracy: 0.9033 - val_loss: 0.4147
# Epoch 121/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 12s 34ms/step - accuracy: 0.9921 - loss: 0.0225 - val_accuracy: 0.9019 - val_loss: 0.4199
# Epoch 122/182
# 351/351 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9928 - loss: 0.0213
